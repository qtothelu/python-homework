# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score? Bitcoin
# 2. Which coin had the highest negative score? Bitcoin
# 3. Which coin had the highest positive score? Bitcoin

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

from newsapi import NewsApiClient
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/quinnluong/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv('.env')
api_key = os.getenv('news_api')

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin", language="en", sort_by="relevancy", page_size=100,
)

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(
    q="ethereum", language="en", sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in bitcoin_news['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]

        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })

    except AttributeError:
        pass

btc_df = pd.DataFrame(btc_sentiments)

cols = ['date', 'text', 'compound', 'positive', 'negative', 'neutral']

btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-05-07  Shares of Square are up more than 6% today aft...    0.2960
# 1  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 2  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 3  2021-04-13  The crypto industry as a whole has seen a mome...    0.6124
# 4  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
#
#    positive  negative  neutral
# 0     0.058       0.0    0.942
# 1     0.000       0.0    1.000
# 2     0.171       0.0    0.829
# 3     0.135       0.0    0.865
# 4     0.000       0.0    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_news['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]

        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })

    except AttributeError:
        pass

eth_df = pd.DataFrame(eth_sentiments)

eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-05-04  Their investors call them disruptive innovator...   -0.2144
# 1  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 2  2021-04-20  Venmo is jumping aboard the cryptocurrency ban...    0.0258
# 3  2021-05-01  New York (CNN Business)Bitcoin prices continue...    0.0000
# 4  2021-05-03  The creators behind CryptoPunks, one of the mo...    0.4754
#
#    positive  negative  neutral
# 0     0.054     0.111    0.835
# 1     0.171     0.000    0.829
# 2     0.034     0.000    0.966
# 3     0.000     0.000    1.000
# 4     0.091     0.000    0.909

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.149250    0.062750    0.024210    0.913060
# std      0.346211    0.071146    0.043991    0.087031
# min     -0.680800    0.000000    0.000000    0.662000
# 25%      0.000000    0.000000    0.000000    0.849750
# 50%      0.000000    0.049000    0.000000    0.920500
# 75%      0.391725    0.103750    0.047250    1.000000
# max      0.845500    0.275000    0.219000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.120525   0.041850   0.009250   0.948900
# std     0.285566   0.059469   0.029097   0.064801
# min    -0.340000   0.000000   0.000000   0.790000
# 25%     0.000000   0.000000   0.000000   0.924000
# 50%     0.000000   0.017000   0.000000   0.964000
# 75%     0.164300   0.056000   0.000000   1.000000
# max     0.817600   0.210000   0.111000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin had the higher mean positive score of 0.062750.
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin also has the highest compound score of 0.2960 recently on May 7.
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin also has the highest positive score of 0.058 recently on May 7.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
print(stopwords.words('do','are','will'))

# Expand the default stopwords list if necessary

# %%
# Complete the tokenizer function
def tokenizer(text):
    sw= set(stopwords.words('english'))
    regex= re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words= word_tokenize(re_clean)
    lem=[lemmatizer.lemmatize(word) for word in words]
    tokens= [word.lower() for word in lem if word.lower() not in sw ]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
nltk.download('reuters')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

btc_df['tokens'] = btc_df.text.apply(tokenizer)
btc_df.head()
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/quinnluong/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/quinnluong/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/quinnluong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/quinnluong/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#          date                                               text  compound  \
# 0  2021-05-07  Shares of Square are up more than 6% today aft...    0.2960
# 1  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 2  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 3  2021-04-13  The crypto industry as a whole has seen a mome...    0.6124
# 4  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
#
#    positive  negative  neutral  \
# 0     0.058       0.0    0.942
# 1     0.000       0.0    1.000
# 2     0.171       0.0    0.829
# 3     0.135       0.0    0.865
# 4     0.000       0.0    1.000
#
#                                               tokens
# 0  [shares, square, today, american, fintech, com...
# 1  [teslas, relationship, bitcoin, dalliance, acc...
# 2  [cryptocurrency, continues, gain, mainstream, ...
# 3  [crypto, industry, whole, ha, seen, momentous,...
# 4  [cryptocurrency, price, continued, tumble, fri...

# %%
# Create a new tokens column for Ethereum
eth_df['tokens'] = eth_df.text.apply(tokenizer)
eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-05-04  Their investors call them disruptive innovator...   -0.2144
# 1  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 2  2021-04-20  Venmo is jumping aboard the cryptocurrency ban...    0.0258
# 3  2021-05-01  New York (CNN Business)Bitcoin prices continue...    0.0000
# 4  2021-05-03  The creators behind CryptoPunks, one of the mo...    0.4754
#
#    positive  negative  neutral  \
# 0     0.054     0.111    0.835
# 1     0.171     0.000    0.829
# 2     0.034     0.000    0.966
# 3     0.000     0.000    1.000
# 4     0.091     0.000    0.909
#
#                                               tokens
# 0  [investor, call, disruptive, innovator, detrac...
# 1  [cryptocurrency, continues, gain, mainstream, ...
# 2  [venmo, jumping, aboard, cryptocurrency, bandw...
# 3  [new, york, cnn, businessbitcoin, price, conti...
# 4  [creator, behind, cryptopunks, one, popular, n...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N=2
btc_n_gram = tokenizer(btc_df.text.str.cat())
btc_counter = Counter(ngrams(btc_n_gram, N))
print(dict(btc_counter))
# Out:
# {('shares', 'square'): 1, ('square', 'today'): 1, ('today', 'american'): 1, ('american', 'fintech'): 1, ('fintech', 'company'): 2, ('company', 'reported'): 1, ('reported', 'staggering'): 1, ('staggering', 'billion'): 1, ('billion', 'revenue'): 1, ('revenue', 'q'): 1, ('q', 'earnings'): 1, ('earnings', 'report'): 1, ('report', 'far'): 1, ('far', 'ahead'): 1, ('ahead', 'expected'): 1, ('expected', 'tally'): 1, ('tally', 'bi'): 1, ('bi', 'charsteslas'): 1, ('charsteslas', 'relationship'): 1, ('relationship', 'bitcoin'): 1, ('bitcoin', 'dalliance'): 1, ('dalliance', 'according'): 1, ('according', 'comment'): 1, ('comment', 'made'): 1, ('made', 'company'): 1, ('company', 'cfo'): 1, ('cfo', 'dubbed'): 1, ('dubbed', 'master'): 1, ('master', 'coin'): 1, ('coin', 'zach'): 1, ('zach', 'kirkhorn'): 1, ('kirkhorn', 'earnings'): 1, ('earnings', 'call'): 1, ('call', 'monday'): 1, ('monday', 'instead'): 1, ('instead', 'compan'): 1, ('compan', 'charscryptocurrency'): 1, ('charscryptocurrency', 'continues'): 1, ('continues', 'gain'): 1, ('gain', 'mainstream'): 1, ('mainstream', 'acceptance'): 1, ('acceptance', 'paypal'): 1, ('paypal', 'announced'): 1, ('announced', 'added'): 1, ('added', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 3, ('ethereum', 'bitcoin'): 1, ('bitcoin', 'cash'): 3, ('cash', 'litecoin'): 1, ('litecoin', 'venmo'): 1, ('venmo', 'app'): 1, ('app', 'user'): 1, ('user', 'base'): 1, ('base', 'million'): 1, ('million', 'mo'): 1, ('mo', 'charsthe'): 1, ('charsthe', 'crypto'): 1, ('crypto', 'industry'): 1, ('industry', 'whole'): 1, ('whole', 'ha'): 1, ('ha', 'seen'): 2, ('seen', 'momentous'): 1, ('momentous', 'year'): 1, ('year', 'growth'): 1, ('growth', 'heavily'): 1, ('heavily', 'spurred'): 1, ('spurred', 'entrance'): 1, ('entrance', 'institutional'): 1, ('institutional', 'investor'): 2, ('investor', 'adopting'): 1, ('adopting', 'bitcoin'): 1, ('bitcoin', 'due'): 1, ('due', 'store'): 1, ('store', 'value'): 1, ('value', 'property'): 1, ('property', 'spike'): 1, ('spike', 'charscryptocurrency'): 1, ('charscryptocurrency', 'price'): 1, ('price', 'continued'): 2, ('continued', 'tumble'): 1, ('tumble', 'friday'): 1, ('friday', 'bitcoin'): 1, ('bitcoin', 'leading'): 1, ('leading', 'charge'): 1, ('charge', 'price'): 1, ('price', 'internet'): 1, ('internet', 'currency'): 1, ('currency', 'dipping'): 1, ('dipping', 'first'): 1, ('first', 'time'): 2, ('time', 'since'): 1, ('since', 'early'): 1, ('early', 'marchbitcoin'): 1, ('marchbitcoin', 'ro'): 1, ('ro', 'charsmark'): 1, ('charsmark', 'zuckerberg'): 1, ('zuckerberg', 'posted'): 1, ('posted', 'picture'): 1, ('picture', 'two'): 1, ('two', 'frankly'): 1, ('frankly', 'adorable'): 1, ('adorable', 'goat'): 1, ('goat', 'noting'): 1, ('noting', 'name'): 1, ('name', 'max'): 1, ('max', 'bitcoinand'): 1, ('bitcoinand', 'say'): 1, ('say', 'ok'): 1, ('ok', 'thenheres'): 1, ('thenheres', 'post'): 1, ('post', 'questionlook'): 1, ('questionlook', 'cute'): 1, ('cute', 'little'): 1, ('little', 'go'): 1, ('go', 'charsimage'): 1, ('charsimage', 'copyrightgetty'): 1, ('copyrightgetty', 'imagesimage'): 1, ('imagesimage', 'captionelon'): 1, ('captionelon', 'musks'): 1, ('musks', 'tesla'): 3, ('tesla', 'ha'): 2, ('seen', 'jump'): 1, ('jump', 'profitstesla'): 1, ('profitstesla', 'ha'): 1, ('ha', 'posted'): 1, ('posted', 'first'): 1, ('first', 'quarter'): 3, ('quarter', 'profit'): 1, ('profit', 'bolstered'): 1, ('bolstered', 'sale'): 1, ('sale', 'bitcoin'): 1, ('bitcoin', 'environmental'): 1, ('environmental', 'credit'): 1, ('credit', 'charsearth'): 1, ('charsearth', 'day'): 1, ('day', 'prime'): 1, ('prime', 'time'): 1, ('time', 'brand'): 1, ('brand', 'people'): 1, ('people', 'promote'): 1, ('promote', 'preexisting'): 1, ('preexisting', 'product'): 1, ('product', 'mass'): 1, ('mass', 'swaddled'): 1, ('swaddled', 'green'): 1, ('green', 'package'): 1, ('package', 'perhaps'): 1, ('perhaps', 'surprise'): 1, ('surprise', 'area'): 1, ('area', 'shaman'): 1, ('shaman', 'jack'): 1, ('jack', 'dorsey'): 1, ('dorsey', 'meme'): 1,  ...

# %%
# Generate the Ethereum N-grams where N=2
eth_n_gram = tokenizer(eth_df.text.str.cat())
eth_counter = Counter(ngrams(eth_n_gram, N))
print(dict(eth_counter))
# Out:
# {('investor', 'call'): 1, ('call', 'disruptive'): 1, ('disruptive', 'innovator'): 1, ('innovator', 'detractors'): 1, ('detractors', 'like'): 1, ('like', 'north'): 1, ('north', 'carolina'): 1, ('carolina', 'attorney'): 1, ('attorney', 'general'): 1, ('general', 'josh'): 1, ('josh', 'stein'): 1, ('stein', 'call'): 1, ('call', 'dirty'): 1, ('dirty', 'scammer'): 1, ('scammer', 'leda'): 1, ('leda', 'health'): 1, ('health', 'cofounder'): 1, ('cofounder', 'madison'): 1, ('madison', 'campbell'): 1, ('campbell', 'liesel'): 1, ('liesel', 'vaidya'): 1, ('vaidya', 'th'): 1, ('th', 'charscryptocurrency'): 1, ('charscryptocurrency', 'continues'): 1, ('continues', 'gain'): 1, ('gain', 'mainstream'): 1, ('mainstream', 'acceptance'): 1, ('acceptance', 'paypal'): 1, ('paypal', 'announced'): 1, ('announced', 'added'): 1, ('added', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 3, ('ethereum', 'bitcoin'): 1, ('bitcoin', 'cash'): 1, ('cash', 'litecoin'): 1, ('litecoin', 'venmo'): 1, ('venmo', 'app'): 1, ('app', 'user'): 1, ('user', 'base'): 1, ('base', 'million'): 1, ('million', 'mo'): 1, ('mo', 'charsvenmo'): 1, ('charsvenmo', 'jumping'): 1, ('jumping', 'aboard'): 1, ('aboard', 'cryptocurrency'): 1, ('cryptocurrency', 'bandwagonthe'): 1, ('bandwagonthe', 'social'): 1, ('social', 'payment'): 1, ('payment', 'service'): 1, ('service', 'announced'): 1, ('announced', 'tuesday'): 1, ('tuesday', 'customer'): 1, ('customer', 'buy'): 1, ('buy', 'hold'): 1, ('hold', 'sell'): 1, ('sell', 'cryptocurrencies'): 1, ('cryptocurrencies', 'within'): 1, ('within', 'venmo'): 1, ('venmo', 'appfour'): 1, ('appfour', 'cr'): 1, ('cr', 'charsnew'): 1, ('charsnew', 'york'): 2, ('york', 'cnn'): 1, ('cnn', 'businessbitcoin'): 1, ('businessbitcoin', 'price'): 1, ('price', 'continued'): 1, ('continued', 'rebound'): 1, ('rebound', 'saturday'): 1, ('saturday', 'rising'): 1, ('rising', 'nearly'): 1, ('nearly', 'world'): 1, ('world', 'largest'): 1, ('largest', 'cryptocurrency'): 1, ('cryptocurrency', 'ha'): 1, ('ha', 'overshadowed'): 1, ('overshadowed', 'lately'): 1, ('lately', 'younger'): 1, ('younger', 'sibling'): 1, ('sibling', 'charsthe'): 1, ('charsthe', 'creator'): 1, ('creator', 'behind'): 1, ('behind', 'cryptopunks'): 1, ('cryptopunks', 'one'): 1, ('one', 'popular'): 1, ('popular', 'nft'): 1, ('nft', 'project'): 1, ('project', 'web'): 1, ('web', 'revealed'): 1, ('revealed', 'latest'): 1, ('latest', 'project'): 1, ('project', 'called'): 1, ('called', 'meebits'): 1, ('meebits', 'project'): 1, ('project', 'boast'): 1, ('boast', 'procedurally'): 1, ('procedurally', 'generated'): 1, ('generated', 'character'): 1, ('character', 'tha'): 1, ('tha', 'charsconsensys'): 1, ('charsconsensys', 'key'): 1, ('key', 'player'): 1, ('player', 'crypto'): 1, ('crypto', 'major'): 1, ('major', 'proponent'): 1, ('proponent', 'ethereum'): 1, ('ethereum', 'blockchain'): 1, ('blockchain', 'ha'): 1, ('ha', 'raised'): 1, ('raised', 'million'): 1, ('million', 'funding'): 1, ('funding', 'round'): 1, ('round', 'fromjp'): 1, ('fromjp', 'morgan'): 1, ('morgan', 'mastercard'): 1, ('mastercard', 'ubs'): 1, ('ubs', 'ag'): 1, ('ag', 'well'): 1, ('well', 'major'): 1, ('major', 'blockchain'): 1, ('blockchain', 'compan'): 1, ('compan', 'charsby'): 1, ('charsby', 'reuters'): 4, ('reuters', 'stafffile'): 2, ('stafffile', 'photo'): 2, ('photo', 'representation'): 2, ('representation', 'virtual'): 4, ('virtual', 'currency'): 4, ('currency', 'ethereum'): 4, ('ethereum', 'seen'): 4, ('seen', 'front'): 4, ('front', 'stock'): 4, ('stock', 'graph'): 4, ('graph', 'illustration'): 4, ('illustration', 'taken'): 4, ('taken', 'february'): 4, ('february', 'reutersdado'): 4, ('reutersdado', 'ruvicillustrationsingapore'): 2, ('ruvicillustrationsingapore', 'charsa'): 1, ('charsa', 'representation'): 2, ('reutersdado', 'ruvicillustrationcryptocurrency'): 2, ('ruvicillustrationcryptocurrency', 'ether'): 2, ('ether', 'hit'): 3, ('hit', 'record'): 3, ('record', 'high'): 3, ('high', 'charsit'): 1, ('charsit', 'took'): 1, ('took', 'get'): 1,  ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_top_10 = token_count(btc_counter, 10)
btc_top_10
# Out:
# [(('charsby', 'reuters'), 18),
#  (('virtual', 'currency'), 14),
#  (('illustration', 'taken'), 14),
#  (('currency', 'bitcoin'), 12),
#  (('representation', 'virtual'), 11),
#  (('seen', 'front'), 11),
#  (('front', 'stock'), 11),
#  (('stock', 'graph'), 11),
#  (('graph', 'illustration'), 11),
#  (('bitcoin', 'seen'), 9)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_top_10 = token_count(eth_counter, 10)
eth_top_10
# Out:
# [(('charsby', 'reuters'), 4),
#  (('representation', 'virtual'), 4),
#  (('virtual', 'currency'), 4),
#  (('currency', 'ethereum'), 4),
#  (('ethereum', 'seen'), 4),
#  (('seen', 'front'), 4),
#  (('front', 'stock'), 4),
#  (('stock', 'graph'), 4),
#  (('graph', 'illustration'), 4),
#  (('illustration', 'taken'), 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
btc_wc = WordCloud(background_color='white').generate(btc_df.text.str.cat())
btc_wc
plt.axis('off')
plt.imshow(btc_wc)

# %%
# Generate the Ethereum word cloud
eth_wc = WordCloud(background_color='white').generate(eth_df.text.str.cat())
eth_wc
plt.axis('off')
plt.imshow(eth_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_concat = btc_df.text.str.cat()
btc_concat
# Out:
# 'Shares of Square are up more than 6% today after the American fintech company reported a staggering $5.06 billion in revenue in its Q1 2021 earnings report, far ahead of an expected tally of $3.36 bi… [+2045 chars]Tesla’s relationship with bitcoin is not a dalliance, according to the comments made by the company’s CFO and dubbed “master of coin” Zach Kirkhorn during an earnings call Monday. Instead, the compan… [+3073 chars]Cryptocurrency continues to gain mainstream acceptance, as PayPal announced that they have added Bitcoin, Ethereum, Bitcoin Cash, and Litecoin to its Venmo app. With a user base of 70 million, the mo… [+2782 chars]The crypto industry as a whole has seen a momentous year of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The 2020 spike… [+4675 chars]Cryptocurrency prices continued to tumble Friday with Bitcoin leading the charge, with prices for the internet currency dipping below $50,000 for the first time since early March.\r\nBitcoin is down ro… [+1222 chars]Mark Zuckerberg posted a picture of his two, frankly adorable, goats noting their names are Max and Bitcoin.\r\nAnd to that I say: OK then.\xa0\r\nHere\'s the post in question.\xa0\r\nLook at those cute little go… [+1482 chars]image copyrightGetty Images\r\nimage captionElon Musk\'s Tesla has seen a jump in profits\r\nTesla has posted first quarter profits of $438m (£315m) bolstered by sales of Bitcoin and environmental credits… [+2702 chars]Earth Day is prime time for brands and people to promote their pre-existing products to the masses, swaddled up in a green package. So perhaps its no surprise that area shaman Jack Dorsey and meme en… [+4711 chars]Three years after its inception, crypto financial service provider Babel Finance is racking up fundings and partnerships from major institutional investors. The startup said Monday that it has closed… [+2610 chars]Venmo is jumping aboard the cryptocurrency bandwagon.\xa0\r\nThe social payment service announced on Tuesday that its customers can now buy, hold, and sell cryptocurrencies within the Venmo app.\xa0\r\nFour cr… [+1524 chars]New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]By Reuters Staff\r\n(Reuters) -MicroStrategy Inc, a major bitcoin corporate backer, said on Monday its non-employee directors will get fees for their services in bitcoin, instead of cash.\r\nShares of th… [+685 chars]The two founders of Crusoe Energy think they may have a solution to two of the largest problems facing the planet today — the increasing energy footprint of the tech industry and the greenhouse gas e… [+7655 chars]Elon Musk really, REALLY likes Dogecoin.\xa0\r\nAfter endlessly shilling the joke cryptocurrency on Twitter, in interviews and on television, and after announcing that his company SpaceX will literally se… [+1228 chars]We\'re going to the moon.\xa0\r\nThe proponents of Dogecoin or DOGE, a cryptocurrency that started as a joke but is now one of the most popular coins around, would have you believe that the sentence above … [+6329 chars]By Reuters Staff\r\nApril 12 (Reuters) - MicroStrategy Inc, a major bitcoin corporate backer, said on Monday its non-employee directors will get fees for their services in bitcoin , instead of cash. (R… [+67 chars]Jack Dorsey, the co-founder and CEO of Twitter, tweeted Wednesday that bitcoin "incentivises renewable energy." And Elon Musk responded "True."The BBC adds that the tweets came "despite experts warni… [+1332 chars]Coinswitch Kuber, a startup that allows young users in India to invest in cryptocurrencies, said on Thursday it has raised $25 million in a new financing round as it looks to expand its reach in Indi… [+2387 chars]By Reuters Staff\r\nApril 18 (Reuters) - Bitcoin, the worlds biggest and best-known cryptocurrency, dro ...

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_concat)
btc_doc
# Add a title to the document
btc_doc.user_data['Title'] = 'BTC NER'

# %%
# Render the visualization
displacy.render(btc_doc, style ='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Shares of Square are up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  fintech company reported a staggering
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $5.06 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in revenue in its Q1
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  earnings report, far ahead of an expected tally of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  bi… [+2045 chars]Tesla’s relationship with bitcoin is not a dalliance, according to the comments made by the company’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CFO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and dubbed “master of coin”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zach Kirkhorn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during an earnings call
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Instead, the compan… [+3073 chars]Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the mo… [+2782 chars]The crypto industry as a whole has seen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a momentous year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  spike… [+4675 chars]Cryptocurrency prices continued to tumble
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leading the charge, with prices for the internet currency dipping below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is down ro… [+1222 chars]Mark
# <mark class="entity" st

# %%
# List all Entities
for i in btc_doc.ents:
    print(i.text, i.label_)
# Out:
# more than 6% PERCENT
# today DATE
# American NORP
# $5.06 billion MONEY
# 2021 DATE
# 3.36 MONEY
# CFO ORG
# Zach Kirkhorn PERSON
# Monday DATE
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# a momentous year DATE
# 2020 DATE
# Friday DATE
# Bitcoin PERSON
# 50,000 MONEY
# first ORDINAL
# early March DATE
# Bitcoin PERSON
# Zuckerberg PERSON
# two CARDINAL
# Max PERSON
# Bitcoin PERSON
# Musk PERSON
# Tesla PERSON
# Tesla PERSON
# first quarter DATE
# $438m MONEY
# 315 MONEY
# Bitcoin ORG
# Jack Dorsey PERSON
# Babel Finance ORG
# Monday DATE
# Tuesday DATE
# Venmo PERSON
# Four CARDINAL
# chars]New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# Reuters ORG
# Reuters ORG
# Inc PERSON
# Monday DATE
# two CARDINAL
# Crusoe Energy ORG
# two CARDINAL
# today DATE
# Musk PERSON
# Dogecoin GPE
# Twitter PRODUCT
# Dogecoin GPE
# Reuters ORG
# April 12 DATE
# Reuters ORG
# Monday DATE
# Dorsey PERSON
# Twitter PRODUCT
# Wednesday DATE
# Elon Musk PERSON
# BBC ORG
# Kuber PERSON
# India GPE
# Thursday DATE
# $25 million MONEY
# Indi GPE
# Reuters ORG
# April 18 DATE
# Reuters ORG
# 7.7% PERCENT
# 55,408.08 MONEY
# Sunday DATE
# 4,624.21 MONEY
# Reuters ORG
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike Blake
#  PERSON
# Reuters ORG
# $27 million MONEY
# Reuters ORG
# LONDON GPE
# April 13 DATE
# Reuters ORG
# 62,575 MONEY
# Tuesday DATE
# 2021 DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin PERSON
# 6.54% PERCENT
# 57,098.08 MONEY
# Friday DATE
# 3,504.11 MONEY
# Reuters ORG
# April 24 DATE
# Reuters ORG
# 1.77% PERCENT
# 50,269.9 MONEY
# Saturday DATE
# 906.75 MONEY
# Bitcoin PERSON
# 22.5 CARDINAL
# Bitcoin PERSON
# April 24, 2020 DATE
# 1.77% PERCENT
# Reuters ORG
# Dec. 8, 2017 DATE
# Benoit Tessier/Illustration/File Photo
#  ORG
# Reuters ORG
# Bitcoin PERSON
# U.S. Dollar ORG
# May 26, 2020 DATE
# 6.8% PERCENT
# $56,852.03 MONEY
# 1000 CARDINAL
# GMT ORG
# Wednesday DATE
# Asian NORP
# Australia GPE
# NZ GPE
# South Korea GPE
# 0.4% PERCENT
# 14% PERCENT
# Sunday DATE
# early Monday DATE
# 24, 2021 DATE
# more than 25% PERCENT
# Millions of dollars MONEY
# 2017 DATE
# first ORDINAL
# Bitcoin PERSON
# Bitcoin PERSON
# Reuters ORG
# May 11 DATE
# Reuters ORG
# Peter Thiel-backed PERSON
# U.S. GPE
# Palantir Technologies Inc ORG
# Tuesday DATE
# Musk PERSON
# Bitcoin PERSON
# Tesla PERSON
# first quarter DATE
# hundreds CARDINAL
# US GPE
# this year DATE
# CNBC ORG
# Wednesday DATE
# NYDIG ORG
# Fidelity Nati PERSON
# 27, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# over 9% PERCENT
# 50,000 MONEY
# CoinDesk ORG
# Monday DATE
# DCENT ORG
# 105 MONEY
# April 21 DATE
# Cesc Maymo PERSON
# first ORDINAL
# North America LOC
# $1 billion MONEY
# just two months DATE
# Bitcoin PERSON
# the Bitcoin Center New York City ORG
# New York's GPE
# July 28, 2015 DATE
# REUTERS ORG
# Brendan McDermidU.S. PERSON
# Tuesday DATE
# Roman Sterlingov PERSON
# Groot GPE
# Daily Crunch WORK_OF_ART
# April 23, 2021 DATE
# Meet Disney Imagineering ORG
# Tom Brady PERSON
# Twitter PRODUCT
# Global Inc ORG
# Wednesday DATE
# $99.6 billion MONEY
# Reuters ORG
# May 6 DATE
# Reuters ORG
# second ORDINAL
# Bitcoin PERSON
# Thursday DATE
# 3,591.65 MONEY
# the Bitstamp Exchange ORG
# about 3 CARDINAL
# as much as 15% PERCENT
# Sunday DATE
# just days DATE
# 64,869 MONEY
# about $56,440 MONEY
# second ORDINAL
# Bitcoin PERSON
# Thursday DATE
# 3,591.65 MONEY
# the Bitstamp Exchange ORG
# about 3.0% PERCENT
# 3,568.92 MONEY
# Bitcoin PERSON
# Friday DATE
# U.S. GPE
# Joe Biden PERSON
# Bitcoin PERSON
# Bitcoin PERSON
# ETH ORG
# Litecoin (LTC ORG
# Bitcoin Cash PERSON
# ATM ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationBitcoin's PERSON
# 13, 2019 DATE
# Costa Mesa GPE
# Sean Culkin PERSON
# the Los Angeles Chargers ORG
# the Hoag Performance Center FAC
# Costa Mesa GPE
# California GPE
# Bitcoin PERSON
# January 8, 2021 DATE
# CME Group Inc ORG
# Tuesday DATE
# April 21 DATE
# Reuters ORG
# Goldman Sachs ORG
# Sachs Group Inc ORG
# Bloomberg News ORG
# Thursday DATE
# Goldman PERSON
# fifth ORDINAL
# U.S. GPE
# Medium ORG
# Tusk PERSON
# Yangs PERSON
# 64,000 MONEY
# first ORDINAL
# U.S. GPE
# 28, 2021 DATE
# Tesla ORG
# Bitcoin PERSON
# the first quarter of 2021 DATE
# the Wall Street Jour ORG
# 65,000 MONEY
# last week DATE
# U.S. GPE
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike BlakeTesla Inc PERSON
# Wednesday DATE
# Dow Jones Indices ORG
# one-month DATE
# Monday DATE
# Tuesday DATE
# Banksy PERSON
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# Reuters ORG
# MicroStrategy Inc ORG
# Reuters ORG
# 13, 2019 DATE
# Costa Mesa GPE
# Sean Culkin PERSON
# the Los Angeles Chargers ORG
# the Hoag Performance Center FAC
# Costa Mesa GPE
# California GPE
# 65,000 MONEY
# last month DATE
# the United St GPE
# Sydney GPE
# Australia GPE
# Jonas Liebschner PERSON
# five and a half month DATE
# Ord/Getty Images ORG
# Bitcoin PERSON
# Fundstrat PERSON
# Tom Lee PERSON
# Wednesday DATE
# recent weeks DATE
# the start of April DATE
# 41% PERCENT
# April DATE
# 8% PERCENT
# as much as 8% PERCENT
# Monday DATE
# five straight days DATE
# almost a fifth CARDINAL
# earlier this month DATE
# Bit PERSON
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Reuters ORG
# May 6 DATE
# Reuters ORG
# quarterly DATE
# Thursday DATE
# 65,000 MONEY
# Dado Ruvic PERSON
# Reuters ORG
# The Securities and Exchange Commission ORG
# Wednesday DATE
# Bitcoin PERSON
# ETH ORG
# Litecoin (LTC ORG
# Bitcoin Cash PERSON
# ATM ORG
# Bitcoin Fund ORG
# Canadian NORP
# 3iQ CARDINAL
# Singapore GPE
# U.S. GPE
# Middle East LOC
# DUBAI PERSON
# April 20 DATE
# Reute ORG
# Musk PERSON
# Tesla PERSON
# Pool/Getty Images ORG
# Bitcoin PERSON
# two-month DATE
# Tuesday DATE
# Elon Musk's PERSON
# chars]Today DATE
# Coinbase NORP
# 250 MONEY
# Coinbase NORP
# 381 MONEY
# today DATE
# around 52% percent PERCENT
# Reuters ORG
# Reuters ORG
# Global Inc PERSON
# more than $91 billion MONEY
# Wednesday DATE
# first ORDINAL
# weekly DATE
# eight CARDINAL
# Bitcoin PERSON
# nearly seven weeks DATE
# Friday DATE
# U.S. GPE
# Bitcoin PERSON
# January 8, 2021 DATE
# Dado RuvicLondon's PERSON
# High Court ORG
# Reuters ORG
# May 11 DATE
# Reuters ORG
# Peter Thiel-backed PERSON
# U.S. GPE
# Tuesday DATE
# the Bitcoin Fund ORG
# Nasdaq Dubai PERSON
# the Middle East's LOC
# first ORDINAL
# German NORP
# Frankfurt GPE
# Germany GPE
# April 14, 2021 DATE
# REUTERS/Staff/File PhotoWorld ORG
# five-day DATE
# Reuters ORG
# April 28 DATE
# Reuters ORG
# $27 million MONEY
# Wednesday DATE
# Dorsey PERSON
# Square FAC
# Twitter PRODUCT
# November 19, 2015 DATE
# Lucas JacksonPayments ORG
# Square Inc ORG
# quarterly DATE
# Friday DATE
# 1% PERCENT
# earlier this week DATE
# nearly seven weeks DATE
# U.S. GPE
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic PERSON
# Dow Jones Indices ORG
# Reuters ORG
# April 13 DATE
# Reuters ORG
# 36% PERCENT
# Wednesday DATE
# weekly DATE
# CoinShares ORG
# Asian NORP
# two days DATE
# Australia GPE
# NZ GPE
# Chinese NORP
# one-month DATE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationBitcoin PERSON
# two CARDINAL
# 4 CARDINAL
# Reuters ORG
# Warren Buffetts PERSON
# Robinhood PRODUCT
# Bitcoin PERSON
# March 15, 2021 DATE
# British NORP
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationInflows PERSON
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Novogratz GPE
# Galaxy Digital ORG
# Rick Wilking PERSON
# Mike Novogratz PERSON
# Sachs Group Inc ORG
# Friday DATE
# Reuters ORG
# Reuters ORG
# March DATE
# chars]NEW YORK GPE
# Reuters ORG
# $4.9 billion MONEY
# April 16 DATE
# the first two weeks of the month DATE
# Bitcoin PERSON
# 2012 DATE
# Bitcoin PERSON
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Reuters ORG
# Porzycki/NurPhoto ORG
# Getty Images ORG
# Tokyo GPE
# Nexon ORG
# Wednesday DATE
# $100 million MONEY

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_concat = eth_df.text.str.cat()
eth_concat
# Out:
# 'Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars]Cryptocurrency continues to gain mainstream acceptance, as PayPal announced that they have added Bitcoin, Ethereum, Bitcoin Cash, and Litecoin to its Venmo app. With a user base of 70 million, the mo… [+2782 chars]Venmo is jumping aboard the cryptocurrency bandwagon.\xa0\r\nThe social payment service announced on Tuesday that its customers can now buy, hold, and sell cryptocurrencies within the Venmo app.\xa0\r\nFour cr… [+1524 chars]New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]The creators behind CryptoPunks, one of the most popular NFT projects on the web, just revealed their latest project called Meebits. The project boasts 20,000 procedurally generated 3D characters tha… [+2000 chars]ConsenSys, a key player in crypto and a major proponent of the Ethereum blockchain, has raised a\xa0$65 million funding round from\xa0J.P. Morgan, Mastercard, and UBS AG, as well as major blockchain compan… [+8767 chars]By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\r\nSINGAPORE… [+748 chars]A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether hit a record high of… [+760 chars]It took a while to get here, but Dfinity is finally launching.\xa0\r\nIn July 2018, I went to the Swiss city of Zug to speak to Dominic Williams, CEO of crypto platform Dfinity. Its blockchain project has… [+4319 chars]This story originally appeared on StockMarketUS Stock Futures Edge Higher On Monday Morning\r\nThe U.S. stock futures moved higher in pre-market trading on Monday as investors prepare themselves for th… [+6451 chars]Non-fungible tokens (NFTs) are quickly becoming go-tos for digital collecting, and that now includes something you might have had as a kid: baseball cards. Topps is launching its first NFT-based base… [+1535 chars]This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nCryptocurrencies are the thing of today. Vitalik Buterin , 27-year-old co-founder of… [+831 chars]By Reuters Staff\r\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending last weeks rally in the wake of a report that the Europe… [+444 chars]A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether extended gains to an… [+632 chars]Posted \r\nThe S&amp;P Dow Jones Indices launched new cryptocurrency indexes, further mainstreaming digital currencies including bitcoin and ethereum by bringing them to the trading floors of Wall Stre… [+30 chars]Sotheby\'s said on Tuesday it would accept bitcoin and ethereum as payment for Banksy\'s iconic artwork "Love is in the Air", a first for a physical art auction and the latest sign of growing mainstrea… [+1176 chars]NEW YORK, May 7 (Reuters) - Ethereum has outperformed major digital currency rivals this year, bolstered by the surge in decentralized finance (DeFi) and the anticipation of a technical adjustment th… [+5345 chars]By Reuters Staff\r\n(Adds detail of reported EIB plan and bitcoin price)\r\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending la… [+684 chars]By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in  ...

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_concat)
eth_doc
# Add a title to the document
eth_doc.user_data['Title'] = 'ETH NER'

# %%
# Render the visualization
displacy.render(eth_doc, style ='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Their investors call them disruptive innovators. Detractors like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Attorney General
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Josh Stein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  call them dirty scammers. But Leda Health co-founders
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison Campbell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liesel Vaidya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  th… [+8679 chars]Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The social payment service announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that its customers can now buy, hold, and sell cryptocurrencies within the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cr… [+1524
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin prices continued their rebound
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , rising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $58,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . But the world's largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]The creators behind
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CryptoPunks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most popular
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  projects on the web, just revealed their latest project called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meebits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The project boasts
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  procedurally generated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %%
# List all Entities
for i in eth_doc.ents:
    print(i.text, i.label_)
# Out:
# North Carolina GPE
# Josh Stein PERSON
# Madison Campbell PERSON
# Liesel Vaidya PERSON
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# Tuesday DATE
# Venmo PERSON
# Four CARDINAL
# chars]New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# CryptoPunks ORG
# one CARDINAL
# NFT ORG
# Meebits PRODUCT
# 20,000 CARDINAL
# 3D ORG
# Ethereum ORG
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# UBS AG ORG
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dfinity ORG
# July 2018 DATE
# Swiss NORP
# Dominic Williams PERSON
# StockMarketUS Stock Futures Edge Higher ORG
# Monday DATE
# U.S. GPE
# Monday DATE
# Topps GPE
# first ORDINAL
# NFT ORG
# Spanish NORP
# AI ORG
# Cryptocurrencies ORG
# today DATE
# Vitalik Buterin PERSON
# 27-year-old DATE
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dow Jones Indices ORG
# Tuesday DATE
# Banksy PERSON
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# chars]NEW YORK GPE
# May 7 DATE
# Reuters ORG
# this year DATE
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# this year DATE
# this summer DATE

# %% [markdown]
# ---
